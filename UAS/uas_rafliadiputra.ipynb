# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/68/LOGO_UEU_BY_ASU-06.png" width=50% height=50%>
#
# <table style="width:75%">
#   <tr>
#     <td><b>Nama</b></td>
#     <td>Rafli Adiputra</td>
#   </tr>
#   <tr>
#     <td><b>NIM</b></td>
#     <td>20200801417</td>
#   </tr>
#   <tr>
#     <td><b>Dosen Pengampu</b></td>
#     <td>Jefry Sunupurwa Asri , S.Kom., M.Kom.</td>
#    </tr>
# </table>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import re
import nltk
from textblob import TextBlob

# %%
file_path = 'uas_nim_ganjil.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# %%
wordcloud = WordCloud(background_color='white').generate(text)

# %%
def preprocess_text(processes_text):
    processes_text = re.sub(r'[^\w\s]', '', text)  
    processes_text = processes_text.lower()  
    return processes_text

processed_text = preprocess_text(text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig('wordcloud.png', bbox_inches='tight', pad_inches=0.2)
plt.show()

# %%
def create_barplot(text):
    tokens = word_tokenize(text)
    fdist = FreqDist(tokens)
    plt.figure(figsize=(10, 5))
    plt.title('Frekunsi Banyaknya Kata Yang Keluar')
    fdist.plot(30, cumulative=False)
    plt.show()

create_barplot(text)

# %%
def get_sentence_polarity(sentence):
    analysis = TextBlob(sentence)
    return analysis.sentiment.polarity
sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
sentiment_scores = [get_sentence_polarity(sentence) for sentence in sentences]

# %%
plt.figure(figsize=(10, 6))
plt.plot(sentiment_scores)
plt.title('Sentiment Analisis dari Kata')
plt.xticks(range(len(sentences)), rotation=90)
plt.show()
